# %%
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf

# %% [markdown]
# ### Data Generation

# %%
observations = 1000

xs = np.random.uniform(low = -10, high = 10, size = (observations,1))
zs = np.random.uniform(-10, 10, (observations,1))
generated_inputs = np.column_stack((xs,zs))

noise = np.random.uniform(-1,1,(observations,1))

generated_targets = 2*xs - 3*zs + 5 + noise

np.savez('TF_intro', inputs = generated_inputs, targets = generated_targets)

# %% [markdown]
# ### Solving with TensorFlow

# %%
training_data = np.load('TF_intro.npz')

# %%
input_size = 2
output_size = 1

model = tf.keras.Sequential([
                            tf.keras.layers.Dense(output_size,
                                                 kernel_initializer=tf.random_uniform_initializer(minval=-0.1,maxval=0.1),
                                                bias_initializer=tf.random_uniform_initializer(minval=-0.1,maxval=0.1)
                                                 )
                            ])

custom_optimizer = tf.keras.optimizers.SGD(learning_rate = 0.02)
model.compile(optimizer=custom_optimizer, loss = 'mean_squared_error') # sgd is the optimization algorthm, MSE is the l2-norm loss function to calculate error
model.fit(training_data['inputs'], training_data['targets'], epochs = 100, verbose = 2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0003s vs `on_train_batch_begin` time: 0.0010s). Check your callbacks.
# 32/32 - 0s - loss: 31.7675
# Epoch 2/100
# 32/32 - 0s - loss: 1.2933
# Epoch 3/100
# 32/32 - 0s - loss: 0.4593
# Epoch 4/100
# 32/32 - 0s - loss: 0.3847
# Epoch 5/100
# 32/32 - 0s - loss: 0.3750
# Epoch 6/100
# 32/32 - 0s - loss: 0.3889
# Epoch 7/100
# 32/32 - 0s - loss: 0.4056
# Epoch 8/100
# 32/32 - 0s - loss: 0.3816
# Epoch 9/100
# 32/32 - 0s - loss: 0.3709
# Epoch 10/100
# 32/32 - 0s - loss: 0.4148
# Epoch 11/100
# 32/32 - 0s - loss: 0.3666
# Epoch 12/100
# 32/32 - 0s - loss: 0.3768
# Epoch 13/100
# 32/32 - 0s - loss: 0.4036
# Epoch 14/100
# 32/32 - 0s - loss: 0.4230
# Epoch 15/100
# 32/32 - 0s - loss: 0.4218
# Epoch 16/100
# 32/32 - 0s - loss: 0.3676
# Epoch 17/100
# 32/32 - 0s - loss: 0.4103
# Epoch 18/100
# 32/32 - 0s - loss: 0.4052
# Epoch 19/100
# 32/32 - 0s - loss: 0.3697
# ...

# %% [markdown]
# ### Extracting the weights and bias

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 2.0279863],
#         [-2.9708028]], dtype=float32),
#  array([4.9711957], dtype=float32)]

# %%
weights = model.layers[0].get_weights()[0]
weights
# Out:
# array([[ 2.0279863],
#        [-2.9708028]], dtype=float32)

# %%
bias = model.layers[0].get_weights()[1]
bias
# Out:
# array([4.9711957], dtype=float32)

# %% [markdown]
# ### Extract outputs(prediction)

# %%
model.predict_on_batch(training_data['inputs']).round(1)
# Out:
# array([[-11.9],
#        [ 28.7],
#        [-11.1],
#        [ -3.7],
#        [ 25.4],
#        [  2.5],
#        [  9.7],
#        [ 14.4],
#        [ 16.9],
#        [ 28.1],
#        [ 22.2],
#        [  0.2],
#        [ 18.4],
#        [ -3.8],
#        [ -6.6],
#        [ -2.2],
#        [ 37. ],
#        [ -9.9],
#        [-13.4],
#        [-13.4],
#        [ 11.4],
#        [-13.8],
#        [ -5.7],
#        [  2.1],
#        [  7.9],
#        [-24.7],
#        [  0.4],
#        [ -3.9],
#        [ 18.1],
#        [  8.9],
#        [ 30.2],
#        [  8.5],
#        [-35.7],
#        [ 28.2],
#        [-11.8],
#        [-12.3],
#        [ -8.4],
#        [-13.6],
#        [ -9.3],
#        [  8.6],
#        [ 10.9],
#        [ -2. ],
#        [ 20.4],
#        [-26.1],
#        [ -1.4],
#        [  0.2],
#        [ 21.9],
#        [-10. ],
#        [ 41. ],
#        [ -1.3],
#        [-12.9],
#        [ -4.3],
#        [ 41.3],
#        [ 13.3],
#        [ 27.2],
# ...

# %%
training_data['targets'].round(1)
# Out:
# array([[-11.2],
#        [ 28.6],
#        [-11.3],
#        [ -3.1],
#        [ 24.7],
#        [  2.1],
#        [  9.4],
#        [ 15.5],
#        [ 15.9],
#        [ 28.3],
#        [ 22.2],
#        [  1.1],
#        [ 18.3],
#        [ -4.6],
#        [ -6.8],
#        [ -2.9],
#        [ 36.6],
#        [ -8.9],
#        [-12.8],
#        [-14. ],
#        [ 11.1],
#        [-13.6],
#        [ -5.4],
#        [  2.8],
#        [  8.8],
#        [-25.4],
#        [  0.1],
#        [ -4.7],
#        [ 18.4],
#        [  8.5],
#        [ 31. ],
#        [  9.2],
#        [-35.5],
#        [ 27.3],
#        [-11.5],
#        [-13.4],
#        [ -7.6],
#        [-13.9],
#        [ -8.9],
#        [  7.6],
#        [  9.7],
#        [ -2.2],
#        [ 20.2],
#        [-26.4],
#        [ -1.5],
#        [  0.2],
#        [ 22.1],
#        [ -8.9],
#        [ 41.1],
#        [ -1.8],
#        [-12.7],
#        [ -5.5],
#        [ 41. ],
#        [ 13.5],
#        [ 26.3],
# ...

# %% [markdown]
# ### plotting the outputs against the targets

# %%
plt.plot(np.squeeze(model.predict_on_batch(training_data['inputs'])), np.squeeze(training_data['targets']))
plt.xlabel('Outputs')
plt.ylabel('Targers')
plt.show()
